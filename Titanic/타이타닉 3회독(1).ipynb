# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5)
import missingno as msno 

import warnings 
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
titanic_train = pd.read_csv('./data/test.csv')
titanic_train
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
titanic_train.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# ## Ticket 과 Fare 를 연관시켜보자

# %%
# titanic_train[['Ticket']].groupby(['Fare'], as_index=True).count()
# 왜 안될까?

# %%
titanic_train['Fare'].isnull()
# Fare 에 Null 값 없음
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: Fare, Length: 418, dtype: bool

# %%
titanic_train['Ticket'].isnull()
# Ticket 에 Null 값 없음
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: Ticket, Length: 418, dtype: bool

# %%
titanic_train['Fare'].max()
# Out:
# 512.3292

# %%
titanic_train['Fare'].values
# Out:
# array([  7.8292,   7.    ,   9.6875,   8.6625,  12.2875,   9.225 ,
#          7.6292,  29.    ,   7.2292,  24.15  ,   7.8958,  26.    ,
#         82.2667,  26.    ,  61.175 ,  27.7208,  12.35  ,   7.225 ,
#          7.925 ,   7.225 ,  59.4   ,   3.1708,  31.6833,  61.3792,
#        262.375 ,  14.5   ,  61.9792,   7.225 ,  30.5   ,  21.6792,
#         26.    ,  31.5   ,  20.575 ,  23.45  ,  57.75  ,   7.2292,
#          8.05  ,   8.6625,   9.5   ,  56.4958,  13.4167,  26.55  ,
#          7.85  ,  13.    ,  52.5542,   7.925 ,  29.7   ,   7.75  ,
#         76.2917,  15.9   ,  60.    ,  15.0333,  23.    , 263.    ,
#         15.5792,  29.125 ,   7.8958,   7.65  ,  16.1   , 262.375 ,
#          7.8958,  13.5   ,   7.75  ,   7.725 , 262.375 ,  21.    ,
#          7.8792,  42.4   ,  28.5375, 263.    ,   7.75  ,   7.8958,
#          7.925 ,  27.7208, 211.5   , 211.5   ,   8.05  ,  25.7   ,
#         13.    ,   7.75  ,  15.2458, 221.7792,  26.    ,   7.8958,
# ...

# %%
fare_values = list()
for value in titanic_train['Fare'] :
#     print(value)
    titanic_train['Fare'].values = round(value)

fare_values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5209                 else:
# -> 5210                     object.__setattr__(self, name, value)
#    5211             except (AttributeError, TypeError):
#
# AttributeError: can't set attribute
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-740d35582bf4> in <module>
#       2 for value in titanic_train['Fare'] :
#       3 #     print(value)
# ----> 4     titanic_train['Fare'].values = round(value)
#       5
#       6 fare_values
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5218                         stacklevel=2,
#    5219                     )
# ...

# %%
titanic['SibSp']+titanic['Parch']+1
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      3
#       ..
# 413    1
# 414    1
# 415    1
# 416    1
# 417    3
# Length: 418, dtype: int64

# %%
titanic_train['Per'] = titanic_train[titanic['Fare'] / titanic['SibSp']+titanic['Parch']+1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-3cd395bfa46c> in <module>
# ----> 1 titanic_train['Per'] = titanic_train[titanic['Fare'] / titanic['SibSp']+titanic['Parch']+1]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# ...

# %%
pd.unique(titanic_train[titanic_train['Fare'] <= 100 ])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-cc2919f06321> in <module>
# ----> 1 pd.unique(titanic_train[titanic_train['Fare'] <= 100 ])
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     393     """
#     394
# --> 395     values = _ensure_arraylike(values)
#     396
#     397     if is_extension_array_dtype(values):
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in _ensure_arraylike(values)
#     206             if isinstance(values, tuple):
#     207                 values = list(values)
# --> 208             values = construct_1d_object_array_from_listlike(values)
#     209         else:
#     210             values = np.asarray(values)
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_object_array_from_listlike(values)
# ...

# %%
titanic_train.loc[(titanic_train['Fare'] < 100) & (titanic_train['Fare'] <= 200) ]
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 412         1304       3                Henriksson, Miss. Jenny Lovisa
# 413         1305       3                            Spector, Mr. Woolf
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# ...

# %%
titanic_train.loc[(titanic_train['Fare'] > 200) & (titanic_train['Fare'] <= 300) ]
# Out:
#      PassengerId  Pclass                                               Name  \
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 53           945       1                         Fortune, Miss. Ethel Flora
# 59           951       1                        Chaudanson, Miss. Victorine
# 64           956       1                        Ryerson, Master. John Borie
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 74           966       1                               Geiger, Miss. Amalie
# 75           967       1                                 Keeping, Mr. Edwin
# 81           973       1                                 Straus, Mr. Isidor
# 114         1006       1             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 142         1034       1                         Ryerson, Mr. Arthur Larned
# 156         1048       1                                  Bird, Miss. Ellen
# ...

# %%
titanic_train.loc[(titanic_train['Fare'] > 300) & (titanic_train['Fare'] <= 400) ]
# 300-400 없다
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
titanic_train.loc[(titanic_train['Fare'] > 400) & (titanic_train['Fare'] <= 500) ]
# 400 - 500 없다
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
titanic_train[titanic_train['Fare'] > 500]
# Out:
#      PassengerId  Pclass                                               Name  \
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 343  female  58.0      0      1  PC 17755  512.3292  B51 B53 B55        C

# %%
titanic_train.Pclass.unique()
# Out:
# array([3, 2, 1], dtype=int64)

# %%
class_1 = list()
for one in titanic_train[titanic_train['Pclass'] == 1]['Ticket'] :
    class_1.append(one)
    
class_1
# Out:
# ['694',
#  '21228',
#  'W.E.P. 5734',
#  'PC 17603',
#  'PC 17598',
#  'PC 17597',
#  'PC 17608',
#  '113509',
#  '113054',
#  '13236',
#  '113778',
#  '11753',
#  'PC 17594',
#  '11813',
#  '13695',
#  '19950',
#  'PC 17608',
#  'PC 17608',
#  '113796',
#  '2543',
#  '19950',
#  'PC 17562',
#  '113503',
#  '113503',
#  '11770',
#  'PC 17483',
#  '19924',
#  'F.C. 12750',
#  '13905',
#  '19877',
#  '11778',
#  'PC 17531',
#  'PC 17483',
#  '13050',
#  '13236',
#  '113780',
#  '113781',
#  'PC 17608',
#  '17475',
#  '17463',
#  '113791',
#  '11767',
#  'PC 17483',
#  '110489',
#  'PC 17591',
#  '17770',
#  '11778',
#  'PC 17756',
#  'PC 17756',
#  '113773',
#  'PC 17558',
#  '111163',
#  '16966',
#  'PC 17757',
#  'F.C. 12998',
#  'PC 17613',
#  '113038',
#  '36928',
#  '113503',
#  'PC 17606',
#  '113795',
#  'PC 17599',
#  '110813',
#  'PC 17761',
#  '112377',
#  '16966',
#  '17464',
#  '13508',
#  '112051',
#  '13050',
#  '13508',
#  '21228',
#  'PC 17607',
#  '33638',
# ...

# %%
class_2 = list()
for two in titanic_train[titanic_train['Pclass'] == 2]['Ticket'] :
    class_2.append(two)
    
class_2
# Out:
# ['240276',
#  '248738',
#  '24065',
#  'SC/PARIS 2167',
#  '233734',
#  'SC/AH 3085',
#  'C.A. 31029',
#  '237249',
#  'SC/PARIS 2168',
#  '29105',
#  'SC/A.3 2861',
#  '237216',
#  'F.C.C. 13534',
#  '248744',
#  '240261',
#  '29103',
#  '228414',
#  '248734',
#  '237734',
#  'SC/AH 29037',
#  'C.A. 33595',
#  '211535',
#  '248659',
#  '244358',
#  '250651',
#  '220844',
#  '237393',
#  '29750',
#  'C.A. 33112',
#  '230136',
#  '233478',
#  '239059',
#  'S.O./P.P. 2',
#  '28221',
#  '226875',
#  '235509',
#  '28220',
#  'C.A. 31030',
#  '26360',
#  'C.A. 34050',
#  '28034',
#  'S.O.C. 14879',
#  '24065',
#  'SC/PARIS 2148',
#  'W./C. 14266',
#  '242963',
#  '220845',
#  '250650',
#  '237789',
#  'F.C.C. 13534',
#  '28220',
#  '26707',
#  'C.A. 34651',
#  '28404',
#  '29103',
#  'C.A. 34644',
#  '236853',
#  'SC 14888',
#  '2926',
#  'CA 31352',
#  'W./C. 14260',
#  'SC/Paris 2123',
#  '237735',
#  'S.O./P.P. 2',
#  '28004',
#  'C.A. 31029',
#  '244368',
#  '230136',
#  '2003',
# ...

# %%
class_3 = list()
for three in titanic_train[titanic_train['Pclass'] == 3]['Ticket'] :
    class_3.append(three)
    
class_3
# titanic_train[titanic_train['Pclass'] == 3]['Ticket']
# Out:
# ['330911',
#  '363272',
#  '315154',
#  '3101298',
#  '7538',
#  '330972',
#  '2657',
#  'A/4 48871',
#  '349220',
#  '2692',
#  'STON/O2. 3101270',
#  '2696',
#  'C 17368',
#  'A/5. 3337',
#  '2698',
#  '2662',
#  'C.A. 2315',
#  'W./C. 6607',
#  '2682',
#  '342712',
#  '315087',
#  '345768',
#  '1601',
#  '349256',
#  'SOTON/O.Q. 3101263',
#  'STON/O 2. 3101291',
#  '370374',
#  'C.A. 37671',
#  '382652',
#  '349230',
#  '348122',
#  '386525',
#  '349232',
#  '347090',
#  '334914',
#  '330963',
#  '382653',
#  '349211',
#  '3101297',
#  '359306',
#  '368702',
#  '2678',
#  '349238',
#  '2660',
#  '330844',
#  'A/4 31416',
#  '364856',
#  '347072',
#  '345498',
#  '376563',
#  '350033',
#  'STON/O 2. 3101268',
#  '347471',
#  'A./5. 3338',
#  '365235',
#  '347070',
#  '2625',
#  'C 4001',
#  '330920',
#  '383162',
#  '3410',
#  '330968',
#  '329944',
#  '2680',
#  '2681',
#  'PP 9549',
#  '367227',
#  '392095',
#  '368783',
#  '371362',
#  '350045',
#  '367226',
#  '342441',
# ...

# %% [markdown]
# # ! 1로 시작하는것, 특정 문자열로 시작하는 것 해서 연관성 찾아서 컬럼에 넣기

# %%
class_1 = list()
for one in titanic_train[titanic_train['Pclass'] == 1]['Cabin'] :
    class_1.append(one)
    
class_1
# Out:
# [nan,
#  'B45',
#  'E31',
#  nan,
#  nan,
#  nan,
#  'B57 B59 B63 B66',
#  'B36',
#  'A21',
#  'C78',
#  'D34',
#  'D19',
#  'A9',
#  'D15',
#  'C31',
#  'C23 C25 C27',
#  'B61',
#  'B57 B59 B63 B66',
#  nan,
#  'C53',
#  'C23 C25 C27',
#  'D43',
#  'C130',
#  'C132',
#  'C101',
#  'C55 C57',
#  nan,
#  'B71',
#  nan,
#  'C46',
#  'C116',
#  'A29',
#  'C55 C57',
#  'C6',
#  'C28',
#  'C51',
#  nan,
#  'B57 B59 B63 B66',
#  nan,
#  'E46',
#  nan,
#  'C54',
#  'C97',
#  'D22',
#  'B10',
#  nan,
#  'C116',
#  'E45',
#  'E52',
#  'D30',
#  'B58 B60',
#  nan,
#  'E34',
#  'C62 C64',
#  nan,
#  'A11',
#  'B11',
#  nan,
#  'C80',
#  nan,
#  nan,
#  'C85',
#  'D37',
#  'C86',
#  nan,
#  'E34',
#  'D21',
#  'C89',
#  nan,
#  'C6',
#  'C89',
#  'B45',
#  nan,
#  'A34',
#  nan,
#  'B26',
#  'C22 C26',
#  'B69',
#  'C32',
#  'B78',
#  nan,
#  nan,
#  nan,
#  'A18',
#  'C106',
#  'B51 B53 B55',
#  'D10 D12',
#  'E60',
#  'C101',
#  'E50',
#  nan,
#  'E39 E41',
#  'B52 B54 B56',
#  'A34',
#  nan,
# ...

# %%
class_2 = list()
for two in titanic_train[titanic_train['Pclass'] == 2]['Cabin'] :
    class_2.append(two)
    
class_2
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'F',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'F4',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'F33',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'D',
#  nan,
#  nan,
#  nan,
#  'F2',
#  'F4',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'D38',
#  nan]

# %%
class_3 = list()
for three in titanic_train[titanic_train['Pclass'] == 3]['Cabin'] :
    class_3.append(three)
    
class_3
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'F G63',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'G6',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %% [markdown]
# ## cabin 은 버리자 흠..
